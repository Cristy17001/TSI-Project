# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhat-Thanh/PixelRL-SR/blob/main/PixelRL-SR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Train**

# %%
# !git clone https://github.com/Nhat-Thanh/PixelRL-SR.git

# %%
# %cd /content/PixelRL-SR/

# %%
# !git pull

# %%
# Train model x2
#!rm -rf dataset/*npy
# !python train.py --scale=2              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x2"
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# dataset/bicubic_train.npy, dataset/data_train.npy and dataset/labels_train.npy HAVE ALREADY EXISTED
#
# dataset/bicubic_validation.npy, dataset/data_validation.npy and dataset/labels_validation.npy HAVE ALREADY EXISTED
#
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# FSRCNN
# SwinIR
# tensor([[[[ 90.3553, 134.2362, 159.5517,  ..., 163.2396, 150.6229, 113.9436],
#           [122.9901, 186.3608, 211.9851,  ..., 215.8379, 203.8823, 136.7471],
#           [141.5376, 189.9834, 222.1145,  ..., 211.7706, 196.7887, 134.6339],
#           ...,
#           [142.7646, 186.4466, 185.5248,  ..., 131.9071, 127.2003,  90.5471],
#           [158.5755, 205.8556, 201.8576,  ..., 139.9877, 138.7479, 101.0702],
#           [124.0276, 148.3544, 138.4481,  ...,  90.9256,  94.5591,  74.1390]],
#
#          [[103.9911, 142.2353, 172.9770,  ..., 182.1990, 168.8523, 121.4391],
#           [133.9531, 186.0708, 214.8080,  ..., 225.5095, 219.9800, 145.8189],
#           [164.2683, 201.3268, 216.9478,  ..., 221.4656, 205.2276, 140.1506],
#           ...,
#           [162.8457, 192.3084, 191.3035,  ...,  97.3871,  93.4463,  66.7210],
#           [172.3314, 208.3017, 204.2352,  ..., 106.1850, 105.8315,  77.4153],
#           [132.5080, 155.5174, 143.4137,  ...,  79.9670,  81.9121,  65.4397]],
#
#          [[124.9415, 156.4638, 197.9772,  ..., 215.0256, 186.4676, 127.0822],
#           [145.4999, 176.4668, 208.9106,  ..., 231.1032, 216.5314, 140.6448],
#           [169.5459, 186.2656, 207.8867,  ..., 222.6850, 201.5169, 132.8532],
#           ...,
#           [185.6409, 198.4005, 189.9216,  ...,  62.7176,  60.8941,  37.0081],
#           [194.9039, 214.5967, 205.3529,  ...,  69.5941,  72.1862,  46.4506],
#           [152.5771, 160.3211, 148.5892,  ...,  47.7021,  50.5183,  39.9117]]],
#
#
#         [[[ 26.8723,  31.4557,  32.1075,  ...,  33.1732,  47.7681,  40.9713],
#           [ 31.1903,  41.1605,  38.0312,  ...,  44.6403,  64.8356,  53.5293],
#           [ 32.5689,  34.8005,  38.0535,  ...,  33.9388,  53.1307,  43.0402],
#           ...,
#           [179.3228, 241.2034, 240.8538,  ..., 209.9041, 204.1653, 148.8762],
#           [183.9551, 244.8960, 246.3932,  ..., 202.8088, 199.2681, 147.2521],
#           [138.4612, 169.0420, 163.3243,  ..., 128.7880, 129.0155, 102.0565]],
#
#          [[ 48.2979,  54.6478,  56.0834,  ...,  55.0170,  69.3055,  56.8671],
#           [ 54.0915,  67.1592,  67.3286,  ...,  65.0204,  88.1582,  67.8434],
#           [ 29.5875,  27.9901,  36.4358,  ...,  29.2781,  34.3502,  30.7051]]],
#
#
#         [[[117.3186, 148.0072, 145.7154,  ..., 150.3044, 139.7649, 109.8702],
#           [145.2553, 198.4118, 195.8279,  ..., 193.0934, 192.1472, 131.5312],
#           [139.1365, 192.2846, 191.1358,  ..., 195.6438, 186.3749, 129.5699],
#           ...,
#           [114.8714, 159.9639, 159.1890,  ...,  89.2049,  92.3852,  72.6525],
#           [123.9656, 165.2542, 168.6927,  ...,  88.5731,  93.2915,  74.5922],
#           [ 85.2681, 107.7638, 107.8678,  ...,  55.6266,  63.0765,  52.4416]],
#
#          [[ 65.3242,  78.9611,  78.5996,  ...,  81.4950,  78.9585,  60.5629],
#           [ 74.1136,  99.4640,  96.2964,  ...,  98.0412, 102.6967,  71.6228],
#           [ 71.5662,  94.0239,  91.0620,  ...,  98.6880,  95.5171,  68.7498],
#           ...,
#           [ 52.3153,  69.1201,  64.2145,  ...,  46.1945,  51.2715,  40.4157],
#           [ 63.6020,  73.6131,  69.9212,  ...,  46.0302,  53.7461,  43.9029],
#           [ 42.7937,  45.1388,  37.7876,  ...,  31.5122,  38.9871,  33.0431]],
#
#          [[100.9954, 113.5665, 118.1817,  ..., 105.0911,  93.0788,  60.7143],
#           [114.8535, 133.4544, 129.0495,  ..., 113.4109, 114.3721,  67.8283],
#           [118.9015, 125.7972, 123.2008,  ..., 115.8752, 113.1952,  66.3167],
#           ...,
#           [ 82.2905,  88.3922,  86.4866,  ...,   4.0388,   1.9866,  -1.3224],
#           [ 86.5505,  95.7436,  97.1553,  ...,   4.4823,   4.2851,   0.7463],
#           [ 63.4686,  66.3322,  67.0191,  ...,  -3.3376,  -5.0150,  -5.8213]]]])
# FSRCNN
# SwinIR
# tensor([[[[ 90.3553, 134.2362, 159.5517,  ..., 163.2396, 150.6229, 113.9436],
#           [122.9901, 186.3608, 211.9851,  ..., 215.8379, 203.8823, 136.7471],
#           [141.5376, 189.9834, 222.1145,  ..., 211.7706, 196.7887, 134.6339],
#           ...,
#           [142.7646, 186.4466, 185.5248,  ..., 131.9071, 127.2003,  90.5471],
#           [158.5755, 205.8556, 201.8576,  ..., 139.9877, 138.7479, 101.0702],
#           [124.0276, 148.3544, 138.4481,  ...,  90.9256,  94.5591,  74.1390]],
#
#          [[103.9911, 142.2353, 172.9770,  ..., 182.1990, 168.8523, 121.4391],
#           [133.9531, 186.0708, 214.8080,  ..., 225.5095, 219.9800, 145.8189],
#           [164.2683, 201.3268, 216.9478,  ..., 221.4656, 205.2276, 140.1506],
#           ...,
#           [162.8457, 192.3084, 191.3035,  ...,  97.3871,  93.4463,  66.7210],
#           [172.3314, 208.3017, 204.2352,  ..., 106.1850, 105.8315,  77.4153],
#           [132.5080, 155.5174, 143.4137,  ...,  79.9670,  81.9121,  65.4397]],
#
#          [[124.9415, 156.4638, 197.9772,  ..., 215.0256, 186.4676, 127.0822],
#           [145.4999, 176.4668, 208.9106,  ..., 231.1032, 216.5314, 140.6448],
#           [169.5459, 186.2656, 207.8867,  ..., 222.6850, 201.5169, 132.8532],
#           ...,
#           [185.6409, 198.4005, 189.9216,  ...,  62.7176,  60.8941,  37.0081],
#           [194.9039, 214.5967, 205.3529,  ...,  69.5941,  72.1862,  46.4506],
#           [152.5771, 160.3211, 148.5892,  ...,  47.7021,  50.5183,  39.9117]]],
#
#
#         [[[ 26.8723,  31.4557,  32.1075,  ...,  33.1732,  47.7681,  40.9713],
#           [ 31.1903,  41.1605,  38.0312,  ...,  44.6403,  64.8356,  53.5293],
#           [ 32.5689,  34.8005,  38.0535,  ...,  33.9388,  53.1307,  43.0402],
#           ...,
#           [179.3228, 241.2034, 240.8538,  ..., 209.9041, 204.1653, 148.8762],
#           [183.9551, 244.8960, 246.3932,  ..., 202.8088, 199.2681, 147.2521],
#           [138.4612, 169.0420, 163.3243,  ..., 128.7880, 129.0155, 102.0565]],
#
#          [[ 48.2979,  54.6478,  56.0834,  ...,  55.0170,  69.3055,  56.8671],
#           [ 54.0915,  67.1592,  67.3286,  ...,  65.0204,  88.1582,  67.8434],
#           [ 57.9350,  65.5577,  63.0835,  ...,  53.5533,  70.3867,  54.0686],
#           ...,
#           [192.7228, 235.9559, 236.2226,  ..., 162.4982, 163.9516, 118.4276],
#           [190.0687, 236.7215, 238.2114,  ..., 161.6423, 161.2519, 117.8200],
#           [144.9443, 172.3033, 164.6882,  ..., 116.8916, 117.9574,  95.2327]],
#
#          [[ 68.2384,  73.3616,  78.2410,  ...,  60.5817,  73.1927,  58.0605],
#           [ 73.6463,  82.9144,  83.6922,  ...,  61.5514,  85.0389,  66.6096],
#           [ 78.0968,  81.0564,  78.3223,  ...,  48.1626,  70.4461,  57.2992],
#           ...,
#           [175.2812, 187.2692, 182.6162,  ..., 102.3696, 104.8757,  68.3183],
#           [180.1139, 194.2365, 190.9223,  ..., 100.3096, 102.1922,  67.9031],
#           [139.6804, 137.7746, 130.1301,  ...,  64.2006,  63.8258,  50.5672]]],
#
#
#         [[[102.1032, 134.9609, 146.3127,  ..., 107.5029, 125.6499, 109.7921],
#           [132.6795, 188.7031, 195.7978,  ..., 145.4458, 179.9671, 142.4468],
#           [138.6484, 170.1343, 189.2378,  ..., 122.1093, 175.2045, 141.5006],
#           ...,
#           [106.1276, 121.8394,  69.7083,  ..., 141.9532, 139.4690, 104.5748],
#           [ 94.2051, 112.0365,  79.9886,  ..., 146.6478, 128.7550,  92.5267],
#           [ 69.2988,  75.9604,  54.0580,  ..., 102.9613,  85.5268,  66.7640]],
#
#          [[139.5316, 170.2641, 185.1237,  ..., 145.6329, 163.9622, 133.2514],
#           [164.9854, 219.8416, 233.4770,  ..., 175.2656, 218.5888, 163.8409],
#           [181.9663, 217.1000, 217.9153,  ..., 154.4478, 202.3926, 159.3448],
#           ...,
#           [135.3150, 140.3111,  87.7652,  ..., 159.8893, 158.6052, 109.6590],
#           [118.2136, 132.0877,  99.5469,  ..., 167.6652, 147.8218,  97.9803],
#           [ 90.7709,  94.1785,  66.8139,  ..., 117.1720, 101.4877,  75.2691]],
#
#          [[161.3754, 179.1856, 191.7135,  ..., 155.7283, 156.1597, 120.1780],
#           [174.8487, 198.2274, 203.8467,  ..., 161.6639, 189.7825, 138.9473],
#           [184.9956, 192.4447, 187.7083,  ..., 138.6069, 179.8231, 139.8972],
#           ...,
#           [106.2192,  98.1430,  55.7840,  ..., 114.3829, 109.3259,  76.1439],
#           [ 97.2683,  93.2496,  66.1965,  ..., 117.1932,  93.7393,  58.6642],
#           [ 77.9034,  62.4845,  41.0958,  ...,  73.5081,  51.9710,  36.4297]]],
#
#
#         ...,
#
#
#         [[[102.5084, 128.8248, 131.0405,  ..., 124.4292, 119.0396,  84.3718],
#           [129.0147, 177.3813, 169.8152,  ..., 163.5426, 162.7051, 105.0261],
#           [133.9025, 163.2992, 171.6866,  ..., 163.8202, 160.9721, 106.0275],
#           ...,
#           [ 53.0043,  65.3395,  68.1074,  ...,  66.4754,  66.7411,  47.4947],
#           [ 58.4596,  73.1868,  74.0076,  ...,  57.1751,  62.6670,  47.5571],
#           [ 48.8214,  55.1881,  52.5377,  ...,  39.3431,  43.9327,  37.0088]],
#
#          [[147.1055, 169.7763, 170.5528,  ..., 162.1126, 156.0676, 115.1437],
#           [165.2880, 207.0791, 206.1283,  ..., 199.5506, 206.4729, 140.4137],
#           [179.2572, 203.4298, 197.2301,  ..., 198.5284, 196.5074, 138.3338],
#           ...,
#           [ 79.7933,  91.7927,  92.7481,  ...,  75.8122,  76.7727,  53.3130],
#           [ 78.1641,  93.0396,  93.4376,  ...,  72.0922,  75.3893,  54.3391],
#           [ 57.7439,  66.3981,  62.4751,  ...,  49.2010,  54.4631,  44.2294]],
#
#          [[205.6252, 223.0280, 233.3980,  ..., 222.0136, 204.8346, 145.4717],
#           [222.5787, 251.2161, 250.2453,  ..., 241.4667, 243.1487, 166.8035],
#           [234.7607, 245.5732, 239.7302,  ..., 238.4178, 237.1568, 167.4741],
#           ...,
#           [111.9640, 120.4525, 119.8052,  ...,  65.6003,  66.7043,  45.8182],
#           [104.9141, 116.7275, 115.3935,  ...,  59.7911,  64.6982,  46.8174],
#           [ 80.3539,  86.1488,  82.7319,  ...,  38.8587,  45.0880,  38.2096]]],
#
#
#         [[[ 91.3191, 124.6339, 133.2223,  ..., 108.6325, 106.3751,  92.1051],
#           [122.2011, 177.3400, 187.5644,  ..., 146.9508, 142.3046, 110.1651],
#           [135.9699, 188.1314, 218.6161,  ..., 142.2825, 143.3269, 109.2266],
#           ...,
#           [ 83.9676, 111.7213, 107.5929,  ..., 108.2955, 107.6056,  81.3790],
#           [ 79.5914, 110.3602, 121.2820,  ..., 116.4437, 116.2194,  87.5753],
#           [ 56.4638,  74.5321,  82.3839,  ...,  81.6820,  82.4894,  65.5118]],
#
#          [[103.2262, 130.6980, 144.5802,  ..., 116.2085, 113.4424,  84.9977],
#           [129.4123, 175.9349, 194.5436,  ..., 142.9039, 143.9684,  99.2218],
#           [154.6820, 199.3412, 221.8743,  ..., 138.8002, 134.9832,  93.3945],
#           ...,
#           [ 91.6170, 111.4336, 107.6074,  ..., 104.3424, 100.5065,  69.6858],
#           [ 83.7470, 107.9061, 117.9209,  ..., 112.7768, 109.0606,  78.2899],
#           [ 62.8649,  77.6102,  84.2056,  ...,  83.3873,  83.3105,  66.9445]],
#
#          [[136.8659, 156.8368, 178.1862,  ...,  73.1407,  68.8045,  48.4388],
#           [158.2265, 185.8029, 202.5593,  ...,  77.1020,  78.7825,  51.1664],
#           [174.7459, 199.3478, 221.7236,  ...,  71.9795,  70.4396,  46.4074],
#           ...,
#           [ 50.7663,  54.1980,  49.8747,  ...,  49.2863,  51.5227,  34.6053],
#           [ 43.5255,  50.1750,  58.6545,  ...,  52.0153,  56.4042,  38.9988],
#           [ 29.5875,  27.9901,  36.4358,  ...,  29.2781,  34.3502,  30.7051]]],
#
#
#         [[[117.3186, 148.0072, 145.7154,  ..., 150.3044, 139.7649, 109.8702],
#           [145.2553, 198.4118, 195.8279,  ..., 193.0934, 192.1472, 131.5312],
#           [139.1365, 192.2846, 191.1358,  ..., 195.6438, 186.3749, 129.5699],
#           ...,
#           [114.8714, 159.9639, 159.1890,  ...,  89.2049,  92.3852,  72.6525],
#           [123.9656, 165.2542, 168.6927,  ...,  88.5731,  93.2915,  74.5922],
#           [ 85.2681, 107.7638, 107.8678,  ...,  55.6266,  63.0765,  52.4416]],
#
#          [[ 65.3242,  78.9611,  78.5996,  ...,  81.4950,  78.9585,  60.5629],
#           [ 74.1136,  99.4640,  96.2964,  ...,  98.0412, 102.6967,  71.6228],
#           [ 71.5662,  94.0239,  91.0620,  ...,  98.6880,  95.5171,  68.7498],
#           ...,
#           [ 52.3153,  69.1201,  64.2145,  ...,  46.1945,  51.2715,  40.4157],
#           [ 63.6020,  73.6131,  69.9212,  ...,  46.0302,  53.7461,  43.9029],
#           [ 42.7937,  45.1388,  37.7876,  ...,  31.5122,  38.9871,  33.0431]],
#
#          [[100.9954, 113.5665, 118.1817,  ..., 105.0911,  93.0788,  60.7143],
#           [114.8535, 133.4544, 129.0495,  ..., 113.4109, 114.3721,  67.8283],
#           [118.9015, 125.7972, 123.2008,  ..., 115.8752, 113.1952,  66.3167],
#           ...,
#           [ 82.2905,  88.3922,  86.4866,  ...,   4.0388,   1.9866,  -1.3224],
#           [ 86.5505,  95.7436,  97.1553,  ...,   4.4823,   4.2851,   0.7463],
#           [ 63.4686,  66.3322,  67.0191,  ...,  -3.3376,  -5.0150,  -5.8213]]]])
# FSRCNN
# SwinIR
# ^C
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/train.py", line 83, in <module>
#     main()
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/train.py", line 80, in main
#     pixelRL_SR.train(train_set, valid_set, BATCH_SIZE, STEPS, SAVE_EVERY, SAVE_LOG)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/model.py", line 137, in train
#     train_reward, train_loss, train_metric = self.train_step(bicubic, lr, hr)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/model.py", line 200, in train_step
#     self.current_state.step(actions, inner_state)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/State.py", line 115, in step
#     swinir_ = to_cpu(self.SwinIR(images_rgb))
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/neuralnet.py", line 990, in forward
#     x = self.conv_after_body(self.forward_features(x)) + x
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/neuralnet.py", line 976, in forward_features
#     x = layer(x, x_size)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/neuralnet.py", line 668, in forward
#     return self.patch_embed(self.conv(self.patch_unembed(self.residual_group(x, x_size), x_size))) + x
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/neuralnet.py", line 588, in forward
#     x = blk(x, x_size)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/neuralnet.py", line 448, in forward
#     attn_windows = self.attn(x_windows, mask=self.calculate_mask(x_size).to(x.device))
# KeyboardInterrupt

# %%
# Train model x3
# !rm -rf dataset/*npy
# !python train.py --scale=3              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x3"

# %%
# Train model x4
# !rm -rf dataset/*npy
# !python train.py --scale=4              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x4"

# %% [markdown]
# #**Test**

# %%
# test on Set5
# !python test.py --scale=2 --ckpt-path="default"
#!python test.py --scale=3 --ckpt-path="default"
#!python test.py --scale=4 --ckpt-path="default"

# %% [markdown]
# #**Demo**

# %%
# !python demo.py --scale=2           \
                --draw-action-map=0 \
                --image-path="dataset/test2.png"

# %% [markdown]
# # **Dataset files**

# %%
# %%writefile dataset-files.sh
#
# OPTION=$1
# DATASET_DIR="/content/PixelRL-SR/dataset"
# DRIVE_DIR="/content/drive/MyDrive/PixelRL-SR"
# SUBSETS=("train" "validation")
# TYPE=("data" "labels" "bicubic")
#
# mkdir -p ${DRIVE_DIR}
# for type in ${TYPE[*]}; do
#     for subset in ${SUBSETS[*]}; do
#         # copy all generated dataset files to your drive
#         if [ "$OPTION" == "copy to drive" ]; then
#             cp -vf ${DATASET_DIR}/${type}_${subset}.npy ${DRIVE_DIR}
#
#         # copy all saved dataset files from your drive to dataset directory
#         elif [ "$OPTION" == "copy from drive" ]; then
#             cp -vf ${DRIVE_DIR}/${type}_${subset}.npy   ${DATASET_DIR}
#
#         # delete all generated dataset files in dataset directory
#         elif [ "${OPTION}" == "remove" ]; then
#             rm -vf ${DATASET_DIR}/${type}_${subset}.npy
#         fi
#     done
# done

# %%
# !bash dataset-files.sh "copy to drive"
# !bash dataset-files.sh "copy from drive"
# !bash dataset-files.sh "remove"

# %% [markdown]
# # **Checkpoint**

# %%
# %%writefile ckpt.sh
# OPTION=$1
#
# DRIVE_DIR="/content/drive/MyDrive/PixelRL-SR"
# SRC="/content/PixelRL-SR/checkpoint"
# DES="${DRIVE_DIR}/checkpoint"
# SUBSETS=("x2" "x3" "x4")
#
# mkdir -p ${DRIVE_DIR}
# for subset in ${SUBSETS[*]}; do
#     # remove all checkpoint files in sub-directories in checkpoint directory
#     if [ "${OPTION}" == "remove" ]; then
#         rm -vrf ${SRC}/${subset}
#         mkdir -p ${SRC}/${subset}
#
#     # copy all checkpoint directories to your drive
#     elif [ "${OPTION}" == "copy to drive" ]; then
#         mkdir -p ${DES}
#         mkdir -p ${DES}/${subset}
#         cp -vrf ${SRC}/${subset}/. ${DES}/${subset}
#
#     # copy all saved checkpoint files from your drive to checkpoint directory
#     elif [ "${OPTION}" == "copy from drive" ]; then
#         mkdir -p ${SRC}
#         mkdir -p ${SRC}/${subset}
#         cp -vrf ${DES}/${subset}/. ${SRC}/${subset}
#     fi
#
# done

# %%
# !bash ckpt.sh "copy from drive"
# !bash ckpt.sh "copy to drive"
# !bash ckpt.sh "remove"
