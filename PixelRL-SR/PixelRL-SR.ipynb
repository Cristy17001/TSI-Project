# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhat-Thanh/PixelRL-SR/blob/main/PixelRL-SR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Train**

# %%
# !git clone https://github.com/Nhat-Thanh/PixelRL-SR.git

# %%
# %cd /content/PixelRL-SR/

# %%
# !git pull

# %%
# Train model x2
#!rm -rf dataset/*npy
# !python train.py --scale=2              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x2"
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# dataset/bicubic_train.npy, dataset/data_train.npy and dataset/labels_train.npy HAVE ALREADY EXISTED
#
# dataset/bicubic_validation.npy, dataset/data_validation.npy and dataset/labels_validation.npy HAVE ALREADY EXISTED
#
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# ESPCN
# Step 50  / 2000 - loss: 2133.060791 - reward: -5035.861816 - PSNR: 11.1517 - val_reward: 41.505058 - val_PSNR: 33.0764
# Save model weights to checkpoint/x2/PixelRL_SR-x2.pt
# Save checkpoint to checkpoint/x2/ckpt-x2.pt
#
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ESPCN
# SwinFIR
# torch.Size([64, 3, 30, 30])
# FSRCNN
# SwinIR
# ^C
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/train.py", line 84, in <module>
#     main()
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/train.py", line 81, in main
#     pixelRL_SR.train(train_set, valid_set, BATCH_SIZE, STEPS, SAVE_EVERY, SAVE_LOG)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/model.py", line 137, in train
#     train_reward, train_loss, train_metric = self.train_step(bicubic, lr, hr)
#   File "/teamspace/studios/this_studio/TSI-Project/PixelRL-SR/model.py", line 199, in train_step
#     actions = Categorical(prob_trans).sample()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/distributions/categorical.py", line 72, in __init__
#     super().__init__(batch_shape, validate_args=validate_args)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/distributions/distribution.py", line 70, in __init__
#     if not valid.all():
# KeyboardInterrupt

# %%
# Train model x3
# !rm -rf dataset/*npy
# !python train.py --scale=3              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x3"

# %%
# Train model x4
# !rm -rf dataset/*npy
# !python train.py --scale=4              \
                 --steps=2000           \
                 --batch-size=64        \
                 --save-every=50        \
                 --save-log=0           \
                 --ckpt-dir="checkpoint/x4"

# %% [markdown]
# #**Test**

# %%
# test on Set5
# !python test.py --scale=2 --ckpt-path="default"
#!python test.py --scale=3 --ckpt-path="default"
#!python test.py --scale=4 --ckpt-path="default"

# %% [markdown]
# #**Demo**

# %%
# !python demo.py --scale=2           \
                --draw-action-map=0 \
                --image-path="dataset/test2.png"

# %% [markdown]
# # **Dataset files**

# %%
# %%writefile dataset-files.sh
#
# OPTION=$1
# DATASET_DIR="/content/PixelRL-SR/dataset"
# DRIVE_DIR="/content/drive/MyDrive/PixelRL-SR"
# SUBSETS=("train" "validation")
# TYPE=("data" "labels" "bicubic")
#
# mkdir -p ${DRIVE_DIR}
# for type in ${TYPE[*]}; do
#     for subset in ${SUBSETS[*]}; do
#         # copy all generated dataset files to your drive
#         if [ "$OPTION" == "copy to drive" ]; then
#             cp -vf ${DATASET_DIR}/${type}_${subset}.npy ${DRIVE_DIR}
#
#         # copy all saved dataset files from your drive to dataset directory
#         elif [ "$OPTION" == "copy from drive" ]; then
#             cp -vf ${DRIVE_DIR}/${type}_${subset}.npy   ${DATASET_DIR}
#
#         # delete all generated dataset files in dataset directory
#         elif [ "${OPTION}" == "remove" ]; then
#             rm -vf ${DATASET_DIR}/${type}_${subset}.npy
#         fi
#     done
# done

# %%
# !bash dataset-files.sh "copy to drive"
# !bash dataset-files.sh "copy from drive"
# !bash dataset-files.sh "remove"

# %% [markdown]
# # **Checkpoint**

# %%
# %%writefile ckpt.sh
# OPTION=$1
#
# DRIVE_DIR="/content/drive/MyDrive/PixelRL-SR"
# SRC="/content/PixelRL-SR/checkpoint"
# DES="${DRIVE_DIR}/checkpoint"
# SUBSETS=("x2" "x3" "x4")
#
# mkdir -p ${DRIVE_DIR}
# for subset in ${SUBSETS[*]}; do
#     # remove all checkpoint files in sub-directories in checkpoint directory
#     if [ "${OPTION}" == "remove" ]; then
#         rm -vrf ${SRC}/${subset}
#         mkdir -p ${SRC}/${subset}
#
#     # copy all checkpoint directories to your drive
#     elif [ "${OPTION}" == "copy to drive" ]; then
#         mkdir -p ${DES}
#         mkdir -p ${DES}/${subset}
#         cp -vrf ${SRC}/${subset}/. ${DES}/${subset}
#
#     # copy all saved checkpoint files from your drive to checkpoint directory
#     elif [ "${OPTION}" == "copy from drive" ]; then
#         mkdir -p ${SRC}
#         mkdir -p ${SRC}/${subset}
#         cp -vrf ${DES}/${subset}/. ${SRC}/${subset}
#     fi
#
# done

# %%
# !bash ckpt.sh "copy from drive"
# !bash ckpt.sh "copy to drive"
# !bash ckpt.sh "remove"
